# %%
import csv
import matplotlib.pyplot as plt

f=open("gender.csv")
data=csv.reader(f)
m=[]
f=[]
name=input("지역을 입력하세요 : ")

for i in data:
    if name in i[0]:
        for j in range(3,104):
            try:
                m.append(int(i[j]))
                f.append(int(i[j+103]))
            except:
                m.append(int(i[j].replace(",","")))
                f.append(int(i[j+103].replace(",","")))
                
    
        break

print(sum(m),sum(f))
plt.plot(m,color="blue",label="m")
plt.plot(f,color="red",label="f")
plt.legend()
plt.show()
# Out:
# 지역을 입력하세요 : 제주특별자치도
# 341096 332827

# %%
import csv
import matplotlib.pyplot as plt

f=open("gender.csv")
data=csv.reader(f)
m=[]
f=[]
result=[]
name=input("지역을 입력하세요 : ")

for i in data:
    if name in i[0]:
        for j in range(3,104):
            try:
                result.append(int(i[j])-int(i[j+103]))
            except:
                result.append(int(i[j].replace(",",""))-int(i[j+103].replace(",","")))
                
    
        break

plt.bar(range(101),result)
plt.show()
# Out:
# 지역을 입력하세요 : 제주특별자치도

# %%
from matplotlib import pyplot as plt
plt.scatter([1,2,3,4],[10,20,30,40],s=[100,200,300,400],c=['red','blue','green','gold'])
plt.show()

# %%
from matplotlib import pyplot as plt
import random as ran
x=[]
y=[]
size=[]
for i in range(100):
    x.append(ran.randint(50,100))
    y.append(ran.randint(50,100))
    size.append(ran.randint(10,100))
    
plt.scatter(x,y,c=size,cmap='jet',alpha=0.6)
plt.colorbar()
plt.show()

# %%
import csv
import matplotlib.pyplot as plt
import math


f=open("gender.csv")
data=csv.reader(f)
m=[]
f=[]
size=[]
name=input("지역을 입력하세요 : ")

for i in data:
    if name in i[0]:
        for j in range(3,104):
            try:
                m.append(int(i[j]))
            except:
                m.append(int(i[j].replace(",","")))
            try:
                f.append(int(i[j+103]))
            except:
                f.append(int(i[j+103].replace(",","")))
                
            
        break

for i in range(len(m)):
    size.append(math.sqrt(m[i]+f[i]))
    
        
plt.rc('font',family='Malgun Gothic')
plt.style.use("ggplot")
plt.figure(figsize=(10,5),dpi=100)

plt.xlabel("남성 인구수")
plt.ylabel("여성 인구수")
plt.title(name+"의 성별비율 그래프")
plt.scatter(m,f,s=size,c=range(101),alpha=0.6,cmap="jet")
plt.plot(range(max(m)),range(max(m)),'g')
plt.colorbar()

plt.show()
# Out:
# 지역을 입력하세요 : 서울

# %%
import numpy as np
import csv
 
# ➊ 데이터를 읽어온다.
f = open('1.csv', 'r', encoding='cp949')
data = csv.reader(f)
next(data)
data = list(data)
 
# ➋ 궁금한 지역의 이름을 입력받는다.
name = input('인구 구조가 알고 싶은 지역의 이름(읍면동 단위)을 입력해주세요 : ')
mn = 1
result_name = ''
result = 0
 
# ➌ 궁금한 지역의 인구 구조를 저장한다.
for row in data :
    if name in row[0] :
        home = np.array(row[3:], dtype=int)/int(row[2])
 
# ➍ 궁금한 지역의 인구 구조와 가장 비슷한 인구 구조를 가진 지역을 찾는다.
for row in data :
    away = np.array(row[3:], dtype=int)/int(row[2])
    s = np.sum((home-away)**2)
    if s < mn and name not in row[0] :
        mn = s
        result_name = row[0]
        result = away
 
# ➎ 궁금한 지역의 인구 구조와 가장 비슷한 곳의 인구 구조를 시각화한다.
import matplotlib.pyplot as plt
plt.style.use('ggplot')
plt.figure(figsize=(10,5), dpi=300)
plt.rc('font', family='Malgun Gothic')
plt.title(name+' 지역과 가장 비슷한 인구 구조를 가진 지역')
plt.plot(home, label=name)
plt.plot(result, label=result_name)
plt.legend()
plt.show()
# Out:
# 인구 구조가 알고 싶은 지역의 이름(읍면동 단위)을 입력해주세요 : 양재2동
